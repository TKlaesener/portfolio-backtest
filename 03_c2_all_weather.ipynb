# %%
import sys
sys.path.append('src')
from metrics import cagr, vol_anualizada, max_drawdown, sharpe
import openpyxl
import pandas as pd
import numpy as np

wb = openpyxl.load_workbook('data/raw/backtest_carteiras.xlsx', data_only=True)
ws = wb['C2_ALL_WEATHER']

# %%
for i, row in enumerate(ws.iter_rows(min_row=1, max_row=35, values_only=True), start=1):
    if row[1] is not None:
        print(i, row[1])
# Out:
# 2   PASSIVA
# 4 Dalio observou que retornos de ativos dependem de 2 variáveis: crescimento (acima/abaixo do esperado) e inflação (acima/abaixo do esperado). Criou 4 quadrantes e alocou ativos que performam em cada um. A grande diferença para a Permanente: pesos não são iguais — são calibrados por risco (volatilidade), não por capital. Ações têm peso menor porque têm volatilidade muito maior. Resultado: carteira menos volátil que 100% ações com retorno competitivo.
# 6 COMPOSIÇÃO ALVO
# 7 ATIVO
# 8 S&P 500 (Ações EUA)
# 9 T-Bond 30a (Bonds longos)
# 10 T-Note 10a (Bonds médios)
# 11 Ouro (Commodities)
# 12 Commodities diversif.
# 15 REGRAS DE REBALANCEAMENTO
# 16 PRINCÍPIO: cada quadrante econômico deve ter ~25% do RISCO (não do capital) da carteira.
# 17 GATILHO: rebalancear quando qualquer ativo desviar >5pp do peso alvo.
# 18 FREQUÊNCIA REVISÃO: trimestral. Rebalanceamento apenas se gatilho ativado.
# 19 APORTE: direcionar para o ativo com maior desvio negativo.
# 20 BONDS: T-Bond e T-Note têm correlação negativa com ações — é isso que reduz o drawdown.
# 21 COMMODITIES: usar GSG (iShares S&P GSCI) ou similar. Para backtest: retorno do índice CRB.
# 22 ADAPTAÇÃO: em ambiente de juros altos (Brasil 2022-24), considerar reduzir T-Bond e aumentar Ouro.
# 23 AVISO: All Weather foi criada para USD. Adaptação para BRL perde parte da correlação negativa bonds/ações.
# 26 MÊS
# 28 INICIO
# 29 Jan/2006
# 30 Feb/2006
# 31 Mar/2006
# 32 Apr/2006
# 33 May/2006
# 34 Jun/2006
# 35 Jul/2006
